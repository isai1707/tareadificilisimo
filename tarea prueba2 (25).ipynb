# %%
lista = []
pes = int(input("How many data do you have? "))
c=pes
i=1
kp=0

while (pes>0):
    numero=float(input("data #"+ str(i) + ": "))
    lista.append(numero)
    i=i+1
    pes = pes-1
    kp=kp+numero

for rep in range(1,len(lista)):
    for dog in range(len(lista)-rep):
        if(lista[dog]>lista[dog+1]):
            temp=lista[dog]
            lista[dog]= lista[dog+1]
            lista[dog+1]= temp
print(lista)

kernel= int(input("give me your porcentage "))
p=kernel/100
x=round(p*c)
if(x==1):
    a=lista.pop(0)
    d=lista.pop(-1)
    print(lista)
    sumwl=kp-a-d
    tm=sumwl/(c-(x*2))
    print("trimmed mean= ",tm)
if(x==2):
    a=lista.pop(0)
    b=lista.pop(-1)
    d=lista.pop(0)
    e=lista.pop(-1)
    print(lista)
    sumwl=kp-a-d-b-e
    tm=sumwl/(c-(x*2))
    print("trimmed mean= ",tm)
if(x==3):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    print(lista)
    sumwl=kp-a-d-b-e-w-q
    tm=sumwl/(c-(x*2))
    print("trimmed mean= ",tm)
if(x==4):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    r=lista.pop(0)
    t=lista.pop(-0)
    print(lista)
    sumwl=kp-a-d-b-e-w-q-r-t
    tm=sumwl/(c-(x*2))
    print("trimmed mean= ",tm)
if(x==5):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    r=lista.pop(0)
    t=lista.pop(-1)
    y=lista.pop(0)
    u=lista.pop(-1)
    print(lista)
    sumwl=kp-a-d-b-e-w-q-r-t-y-u
    tm=sumwl/(c-(x*2))
    print("trimmed mean= ",tm)
if(x==6):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    r=lista.pop(0)
    t=lista.pop(-1)
    y=lista.pop(0)
    u=lista.pop(-1)
    s=lista.pop(0)
    f=lista.pop(-1)
    print(lista)
    sumwl=kp-a-d-b-e-w-q-r-t-y-u-s-f
    tm=sumwl/(c-(x*2))
    print("trimmed mean= ",tm)
if(x==7):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    r=lista.pop(0)
    t=lista.pop(-1)
    y=lista.pop(0)
    u=lista.pop(-1)
    s=lista.pop(0)
    f=lista.pop(-1)
    g=lista.pop(0)
    h=lista.pop(-1)
    print(lista)
    sumwl=kp-a-d-b-e-w-q-r-t-y-u-s-f-g-h
    tm=sumwl/(c-(x*2))
    print("trimmed mean= ",tm)
if(x==8):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    r=lista.pop(0)
    t=lista.pop(-1)
    y=lista.pop(0)
    u=lista.pop(-1)
    s=lista.pop(0)
    f=lista.pop(-1)
    g=lista.pop(0)
    h=lista.pop(-1)
    j=lista.pop(0)
    k=lista.pop(-1)
    print(lista)
    sumwl=kp-a-d-b-e-w-q-r-t-y-u-s-f-g-h-j-k
    tm=sumwl/(c-(x*2))
    print("trimmed mean= ",tm)
if(x==9):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    r=lista.pop(0)
    t=lista.pop(-1)
    y=lista.pop(0)
    u=lista.pop(-1)
    s=lista.pop(0)
    f=lista.pop(-1)
    g=lista.pop(0)
    h=lista.pop(-1)
    j=lista.pop(0)
    k=lista.pop(-1)
    l=lista.pop(0)
    ñ=lista.pop(-1)
    print(lista)
    sumwl=kp-a-d-b-e-w-q-r-t-y-u-s-f-g-h-j-k-l-ñ
    tm=sumwl/(c-(x*2))
    print("trimmed mean= ",tm)
if(x==10):
    a=lista.pop(0)
    b=lista.pop(0)
    q=lista.pop(0)
    d=lista.pop(-1)
    e=lista.pop(-1)
    w=lista.pop(-1)
    r=lista.pop(0)
    t=lista.pop(-1)
    y=lista.pop(0)
    u=lista.pop(-1)
    s=lista.pop(0)
    f=lista.pop(-1)
    g=lista.pop(0)
    h=lista.pop(-1)
    j=lista.pop(0)
    k=lista.pop(-1)
    l=lista.pop(0)
    ñ=lista.pop(-1)
    n=lista.pop(0)
    m=lista.pop(-1)
    print(lista)
    sumwl=kp-a-d-b-e-w-q-r-t-y-u-s-f-g-h-j-k-l-ñ-n-m
    tm=sumwl/(c-(x*2))
    print("trimmed mean= ",tm)

    print("you have a error give more data")
# Out:
# How many data do you have? 10
# data #1: 4
# data #2: 5
# data #3: 6
# data #4: 7
# data #5: 25
# data #6: 46
# data #7: 49
# data #8: 46
# data #9: 52
# data #10: 10
# [4.0, 5.0, 6.0, 7.0, 10.0, 25.0, 46.0, 46.0, 49.0, 52.0]
# give me your porcentage 10
# [5.0, 6.0, 7.0, 10.0, 25.0, 46.0, 46.0, 49.0]
# trimmed mean=  24.25
